# %%
# pip install requests beautifulsoup4 pandas sqlalchemy pymysql python-dotenv notebook

# %%
# pip freeze > requirements.txt

# %%
from dotenv import load_dotenv
import os

# Load .env file
load_dotenv("DB.env")

# Fetch values
DB_USER = os.getenv("DB_USER")
DB_PASS = os.getenv("DB_PASS")
DB_HOST = os.getenv("DB_HOST")
DB_NAME = os.getenv("DB_NAME")

print("Loaded credentials:")
print(DB_USER, DB_HOST, DB_NAME)  # (Don't worry, password won't print)
# Out:
# Loaded credentials:
# None None None

# %%
# pip install cryptography

# %%
from dotenv import load_dotenv
import os

# Load environment variables from db.env
load_dotenv("db.env")

DB_USER = os.getenv("DB_USER")
DB_PASS = os.getenv("DB_PASS")
DB_HOST = os.getenv("DB_HOST")
DB_NAME = os.getenv("DB_NAME")

print("Loaded DB_NAME =", DB_NAME)
# Out:
# Loaded DB_NAME = None

# %%
from sqlalchemy import create_engine
import pandas as pd
from dotenv import load_dotenv
import os

# Load from .env
load_dotenv(override=True)

DB_USER = os.getenv("DB_USER")
DB_PASS = os.getenv("DB_PASS")
DB_HOST = os.getenv("DB_HOST")
DB_NAME = os.getenv("DB_NAME")

print("Loaded DB_NAME =", DB_NAME)

# Create database engine
engine = create_engine(f"mysql+pymysql://{DB_USER}:{DB_PASS}@{DB_HOST}/{DB_NAME}")

try:
    df = pd.read_sql("SELECT NOW()", con=engine)
    print("✅ Database connection successful!")
    print(df)
except Exception as e:
    print("❌ Error connecting to database:", e)
# Out:
# Loaded DB_NAME = book_scraper
# ✅ Database connection successful!
#                 NOW()
# 0 2025-09-06 00:24:53
